# %% [markdown]
# <a href="https://colab.research.google.com/github/Archith34/CodeAlpha_hangman_game/blob/main/hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
stages=['''
    -----
    |   |
    O   |
   /|\  |
   / \  |
        |
----------
''','''
    -----
    |   |
    O   |
   /|\  |
   /    |
        |
----------
''','''
    -----
    |   |
    O   |
   /|\  |
        |
        |
----------
''','''
    -----
    |   |
    O   |
   /|   |
        |
        |
----------
''','''
    -----
    |   |
    O   |
    |   |
        |
        |
----------
''','''
    -----
    |   |
    O   |
        |
        |
        |
----------
''','''
    -----
    |   |
        |
        |
        |
        |
----------
''']
word_list=["apple","codealpha","college"]
lives=6
chosen_word=random.choice(word_list)
print(chosen_word)
display=[]
for i in range(len(chosen_word)):
  display+="_"
print(display)
game_over=False
while not game_over:
  guessed_letter=input("guess a letter:").lower()
  for position in range(len(chosen_word)):
    letter=chosen_word[position]
    if letter==guessed_letter:
      display[position]=guessed_letter
  print(display)
  if guessed_letter not in chosen_word:
    lives-=1
    if lives==0:
     game_over=True
     print("you lose")
  if "_" not in display:
   game_over=True
   print("you win")
  print(stages[lives])
# Out:
# apple
# ['_', '_', '_', '_', '_']
# guess a letter:a
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#         |
#         |
#         |
#         |
# ----------
#
# guess a letter:g
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#     O   |
#         |
#         |
#         |
# ----------
#
# guess a letter:g
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#         |
# ----------
#
# guess a letter:j
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|   |
#         |
#         |
# ----------
#
# guess a letter:s
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|\  |
#         |
#         |
# ----------
#
# guess a letter:r
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|\  |
#    /    |
#         |
# ----------
#
# guess a letter:w
# ['a', '_', '_', '_', '_']
# you lose
#
#     -----
#     |   |
#     O   |
#    /|\  |
#    / \  |
#         |
# ----------
